# %% [markdown]
# # 收益率分析

# %%
import datetime as dt

import yfinance as yf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.ticker import PercentFormatter

import warnings
warnings.filterwarnings("ignore")

plt.style.use("ggplot")

# %% [markdown]
# ## 准备数据

# %%
ticker = "BTC-USD"
start = dt.datetime(2012, 1, 1)
end = dt.datetime.today()
output_file = "../data/yahoo_btcusd.csv"

data = yf.download(ticker, start=start, end=end)
data.to_csv(output_file)
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2024-03-22  65489.929688  66623.750000  62355.371094  63778.761719
# 2024-03-23  63802.722656  65976.398438  63038.492188  64062.203125
# 2024-03-24  64070.753906  67622.757812  63825.851562  67234.171875
# 2024-03-25  67234.093750  71162.593750  66414.835938  69958.812500
# 2024-03-26  69906.226562  71511.523438  69781.140625  70684.398438
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# 2014-09-19    394.795990     37919700
# 2014-09-20    408.903992     36863600
# 2014-09-21    398.821014     26580100
# ...                  ...          ...
# 2024-03-22  63778.761719  41401116964
# 2024-03-23  64062.203125  24738964812
# 2024-03-24  67234.171875  27206630673
# 2024-03-25  69958.812500  42700139523
# 2024-03-26  70684.398438  44048654336
#
# [3479 rows x 6 columns]

# %% [markdown]
# ## 月收益率
#
# 将日数据重采样为月，计算每天平均，然后计算月收益率。

# %%
monthly_data = data.resample("MS").mean()
monthly_returns = monthly_data["Close"].pct_change().dropna()
monthly_returns.index = [monthly_returns.index.year, monthly_returns.index.month]
monthly_returns_df = monthly_returns.unstack(level=0)
monthly_returns_df.index = ["Jan", "Feb", "Mar", "Apr", "May", "Jun", "Jul", "Aug", "Sep", "Oct", "Nov", "Dec"]
# monthly_returns_df

# %%
def color_cell(val):
    if np.isnan(val):
        return "color: transparent"
    if val > 0.05:
        return "color: lime"
    elif val < -0.05:
        return "color: red"
    else:
        return "color: yellow"

monthly_returns_df.style.map(color_cell).format("{:.1%}")
# Out:
# <style type="text/css">
# #T_e4258_row0_col0, #T_e4258_row1_col0, #T_e4258_row2_col0, #T_e4258_row3_col0, #T_e4258_row3_col10, #T_e4258_row4_col0, #T_e4258_row4_col10, #T_e4258_row5_col0, #T_e4258_row5_col10, #T_e4258_row6_col0, #T_e4258_row6_col10, #T_e4258_row7_col0, #T_e4258_row7_col10, #T_e4258_row8_col0, #T_e4258_row8_col10, #T_e4258_row9_col10, #T_e4258_row10_col10, #T_e4258_row11_col10 {
#   color: transparent;
# }
# #T_e4258_row0_col1, #T_e4258_row0_col4, #T_e4258_row0_col8, #T_e4258_row1_col1, #T_e4258_row1_col4, #T_e4258_row2_col6, #T_e4258_row3_col1, #T_e4258_row3_col4, #T_e4258_row4_col7, #T_e4258_row4_col8, #T_e4258_row5_col4, #T_e4258_row5_col7, #T_e4258_row5_col8, #T_e4258_row6_col8, #T_e4258_row7_col1, #T_e4258_row7_col2, #T_e4258_row7_col4, #T_e4258_row7_col9, #T_e4258_row8_col1, #T_e4258_row8_col5, #T_e4258_row8_col6, #T_e4258_row8_col8, #T_e4258_row8_col9, #T_e4258_row9_col0, #T_e4258_row9_col5, #T_e4258_row10_col4, #T_e4258_row10_col8, #T_e4258_row11_col0, #T_e4258_row11_col4, #T_e4258_row11_col5, #T_e4258_row11_col7 {
#   color: red;
# }
# #T_e4258_row0_col2, #T_e4258_row0_col5, #T_e4258_row0_col10, #T_e4258_row1_col2, #T_e4258_row1_col5, #T_e4258_row1_col8, #T_e4258_row2_col2, #T_e4258_row2_col4, #T_e4258_row2_col8, #T_e4258_row3_col2, #T_e4258_row3_col7, #T_e4258_row3_col8, #T_e4258_row4_col1, #T_e4258_row4_col9, #T_e4258_row5_col1, #T_e4258_row5_col6, #T_e4258_row5_col9, #T_e4258_row6_col2, #T_e4258_row6_col3, #T_e4258_row6_col6, #T_e4258_row6_col7, #T_e4258_row7_col5, #T_e4258_row7_col8, #T_e4258_row8_col2, #T_e4258_row8_col3, #T_e4258_row8_col4, #T_e4258_row8_col7, #T_e4258_row9_col4, #T_e4258_row9_col8, #T_e4258_row10_col0, #T_e4258_row10_col5, #T_e4258_row10_col7, #T_e4258_row11_col8 {
#   color: yellow;
# }
# #T_e4258_row0_col3, #T_e4258_row0_col6, #T_e4258_row0_col7, #T_e4258_row0_col9, #T_e4258_row1_col3, #T_e4258_row1_col6, #T_e4258_row1_col7, #T_e4258_row1_col9, #T_e4258_row1_col10, #T_e4258_row2_col1, #T_e4258_row2_col3, #T_e4258_row2_col5, #T_e4258_row2_col7, #T_e4258_row2_col9, #T_e4258_row2_col10, #T_e4258_row3_col3, #T_e4258_row3_col5, #T_e4258_row3_col6, #T_e4258_row3_col9, #T_e4258_row4_col2, #T_e4258_row4_col3, #T_e4258_row4_col4, #T_e4258_row4_col5, #T_e4258_row4_col6, #T_e4258_row5_col2, #T_e4258_row5_col3, #T_e4258_row5_col5, #T_e4258_row6_col1, #T_e4258_row6_col4, #T_e4258_row6_col5, #T_e4258_row6_col9, #T_e4258_row7_col3, #T_e4258_row7_col6, #T_e4258_row7_col7, #T_e4258_row9_col1, #T_e4258_row9_col2, #T_e4258_row9_col3, #T_e4258_row9_col6, #T_e4258_row9_col7, #T_e4258_row9_col9, #T_e4258_row10_col1, #T_e4258_row10_col2, #T_e4258_row10_col3, #T_e4258_row10_col6, #T_e4258_row10_col9, #T_e4258_row11_col1, #T_e4258_row11_col2, #T_e4258_row11_col3, #T_e4258_row11_col6, #T_e4258_row11_col9 {
#   color: lime;
# }
# </style>
# <table id="T_e4258">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Date</th>
#       <th id="T_e4258_level0_col0" class="col_heading level0 col0" >2014</th>
#       <th id="T_e4258_level0_col1" class="col_heading level0 col1" >2015</th>
#       <th id="T_e4258_level0_col2" class="col_heading level0 col2" >2016</th>
#       <th id="T_e4258_level0_col3" class="col_heading level0 col3" >2017</th>
#       <th id="T_e4258_level0_col4" class="col_heading level0 col4" >2018</th>
#       <th id="T_e4258_level0_col5" class="col_heading level0 col5" >2019</th>
#       <th id="T_e4258_level0_col6" class="col_heading level0 col6" >2020</th>
#       <th id="T_e4258_level0_col7" class="col_heading level0 col7" >2021</th>
#       <th id="T_e4258_level0_col8" class="col_heading level0 col8" >2022</th>
#       <th id="T_e4258_level0_col9" class="col_heading level0 col9" >2023</th>
#       <th id="T_e4258_level0_col10" class="col_heading level0 col10" >2024</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4258_level0_row0" class="row_heading level0 row0" >Jan</th>
#       <td id="T_e4258_row0_col0" class="data row0 col0" >nan%</td>
#       <td id="T_e4258_row0_col1" class="data row0 col1" >-27.1%</td>
#       <td id="T_e4258_row0_col2" class="data row0 col2" >-3.2%</td>
#       <td id="T_e4258_row0_col3" class="data row0 col3" >10.5%</td>
#       <td id="T_e4258_row0_col4" class="data row0 col4" >-14.4%</td>
#       <td id="T_e4258_row0_col5" class="data row0 col5" >-0.4%</td>
#       <td id="T_e4258_row0_col6" class="data row0 col6" >15.2%</td>
#       <td id="T_e4258_row0_col7" class="data row0 col7" >58.1%</td>
#       <td id="T_e4258_row0_col8" class="data row0 col8" >-16.5%</td>
#       <td id="T_e4258_row0_col9" class="data row0 col9" >19.5%</td>
#       <td id="T_e4258_row0_col10" class="data row0 col10" >0.9%</td>
#     </tr>
#     <tr>
#       <th id="T_e4258_level0_row1" class="row_heading level0 row1" >Feb</th>
#       <td id="T_e4258_row1_col0" class="data row1 col0" >nan%</td>
#       <td id="T_e4258_row1_col1" class="data row1 col1" >-5.9%</td>
#       <td id="T_e4258_row1_col2" class="data row1 col2" >-1.6%</td>
#       <td id="T_e4258_row1_col3" class="data row1 col3" >16.1%</td>
#       <td id="T_e4258_row1_col4" class="data row1 col4" >-27.6%</td>
#       <td id="T_e4258_row1_col5" class="data row1 col5" >0.3%</td>
#       <td id="T_e4258_row1_col6" class="data row1 col6" >14.8%</td>
#       <td id="T_e4258_row1_col7" class="data row1 col7" >33.2%</td>
#       <td id="T_e4258_row1_col8" class="data row1 col8" >-0.9%</td>
#       <td id="T_e4258_row1_col9" class="data row1 col9" >15.1%</td>
#       <td id="T_e4258_row1_col10" class="data row1 col10" >16.2%</td>
#     </tr>
#     <tr>
#       <th id="T_e4258_level0_row2" class="row_heading level0 row2" >Mar</th>
#       <td id="T_e4258_row2_col0" class="data row2 col0" >nan%</td>
#       <td id="T_e4258_row2_col1" class="data row2 col1" >14.9%</td>
#       <td id="T_e4258_row2_col2" class="data row2 col2" >3.0%</td>
#       <td id="T_e4258_row2_col3" class="data row2 col3" >6.3%</td>
#       <td id="T_e4258_row2_col4" class="data row2 col4" >-4.6%</td>
#       <td id="T_e4258_row2_col5" class="data row2 col5" >7.1%</td>
#       <td id="T_e4258_row2_col6" class="data row2 col6" >-28.7%</td>
#       <td id="T_e4258_row2_col7" class="data row2 col7" >18.8%</td>
#       <td id="T_e4258_row2_col8" class="data row2 col8" >3.0%</td>
#       <td id="T_e4258_row2_col9" class="data row2 col9" >7.8%</td>
#       <td id="T_e4258_row2_col10" class="data row2 col10" >34.8%</td>
#     </tr>
#     <tr>
#       <th id="T_e4258_level0_row3" class="row_heading level0 row3" >Apr</th>
#       <td id="T_e4258_row3_col0" class="data row3 col0" >nan%</td>
#       <td id="T_e4258_row3_col1" class="data row3 col1" >-12.5%</td>
#       <td id="T_e4258_row3_col2" class="data row3 col2" >4.3%</td>
#       <td id="T_e4258_row3_col3" class="data row3 col3" >6.8%</td>
#       <td id="T_e4258_row3_col4" class="data row3 col4" >-11.1%</td>
#       <td id="T_e4258_row3_col5" class="data row3 col5" >30.2%</td>
#       <td id="T_e4258_row3_col6" class="data row3 col6" >5.1%</td>
#       <td id="T_e4258_row3_col7" class="data row3 col7" >4.0%</td>
#       <td id="T_e4258_row3_col8" class="data row3 col8" >-1.3%</td>
#       <td id="T_e4258_row3_col9" class="data row3 col9" >14.9%</td>
#       <td id="T_e4258_row3_col10" class="data row3 col10" >nan%</td>
#     </tr>
#     <tr>
#       <th id="T_e4258_level0_row4" class="row_heading level0 row4" >May</th>
#       <td id="T_e4258_row4_col0" class="data row4 col0" >nan%</td>
#       <td id="T_e4258_row4_col1" class="data row4 col1" >0.6%</td>
#       <td id="T_e4258_row4_col2" class="data row4 col2" >6.4%</td>
#       <td id="T_e4258_row4_col3" class="data row4 col3" >57.1%</td>
#       <td id="T_e4258_row4_col4" class="data row4 col4" >5.2%</td>
#       <td id="T_e4258_row4_col5" class="data row4 col5" >41.2%</td>
#       <td id="T_e4258_row4_col6" class="data row4 col6" >28.2%</td>
#       <td id="T_e4258_row4_col7" class="data row4 col7" >-18.8%</td>
#       <td id="T_e4258_row4_col8" class="data row4 col8" >-23.5%</td>
#       <td id="T_e4258_row4_col9" class="data row4 col9" >-4.7%</td>
#       <td id="T_e4258_row4_col10" class="data row4 col10" >nan%</td>
#     </tr>
#     <tr>
#       <t

# %% [markdown]
# ## 季节性效应
#
# 计算月收益率，然后按照月份进行分类，创建箱线图，查看季节性效应。

# %%
monthly_data = data.resample("MS").mean()
monthly_data["return"] = monthly_data["Close"].pct_change()
monthly_data["month"] = monthly_data.index.month_name()
monthly_data.dropna(inplace=True)
# monthly_data

# %%
month_order_list = ["January", "February", "March", "April", "May", "June", "July", "August", "September", "October", "November", "December"]
fig, ax = plt.subplots(figsize=(8, 5))
sns.boxplot(x="month", y="return", data=monthly_data, ax=ax, order=month_order_list)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_xlabel("")
ax.set_ylabel("Monthly return")
ax.yaxis.set_major_formatter(PercentFormatter(1))
_ = ax.set_title("Monthly returns of BTC-USD")
