# %% [markdown]
# # 高收益信贷利率

# %%
import datetime as dt

import pandas_datareader as pdr
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")

# %% [markdown]
# 下载高收益债券收益率，ICE BofA US High Yield Index Effective Yield

# %%
# series_id = "BAMLH0A0HYM2EY"
# start_date = "2000-01-01"
# end_date = "2024-04-01"

# data = pdr.get_data_fred(series_id, start=start_date, end=end_date)

# %%
# data.to_csv("../data/high_yield_bond_rates.csv", index=True)

# %% [markdown]
# 读取BTC历史价格，合并数据，然后绘制图表

# %%
btc_prices = pd.read_csv("../data/bitstamp_btcusd_1d.csv", index_col=0, parse_dates=True,
                         usecols=["timestamp", "close"])
btc_prices.index.name = "date"
btc_prices
# Out:
#                close
# date
# 2012-01-01      5.00
# 2012-01-02      5.00
# 2012-01-03      5.29
# 2012-01-04      5.57
# 2012-01-05      6.65
# ...              ...
# 2024-02-26  54524.00
# 2024-02-27  57068.00
# 2024-02-28  62512.00
# 2024-02-29  61161.00
# 2024-03-01  62444.00
#
# [4444 rows x 1 columns]

# %%
high_yield_bond_rates = pd.read_csv("../data/high_yield_bond_rates.csv", index_col=0, parse_dates=True)
high_yield_bond_rates.index.name = "date"
high_yield_bond_rates.rename(columns={"BAMLH0A0HYM2EY": "bond_rate"}, inplace=True)
high_yield_bond_rates
# Out:
#             bond_rate
# date
# 2000-01-03      11.39
# 2000-01-04      11.43
# 2000-01-05      11.47
# 2000-01-06      11.47
# 2000-01-07      11.47
# ...               ...
# 2024-03-11       7.50
# 2024-03-12       7.50
# 2024-03-13       7.48
# 2024-03-14       7.57
# 2024-03-15       7.61
#
# [6395 rows x 1 columns]

# %% [markdown]
# BTC一周交易7天，债券利率周末没有数据，合并数据时以BTC索引为准，缺失的利率数据用前值填充。

# %%
data = pd.merge(btc_prices, high_yield_bond_rates,
                how="outer", left_index=True, right_index=True)
data = data.asfreq("D")  # fill in missing dates
data.ffill(inplace=True)  # fill in missing bond rates

# window = 365*4
# data["bond_rate_rolling_percent_rank"] = data["bond_rate"].rolling(window).rank(pct=True)
# data.dropna(inplace=True)

data = data.loc["2012-01-01":"2024-02-29"]
data.head(20)
# Out:
#             close  bond_rate
# date
# 2012-01-01   5.00       8.29
# 2012-01-02   5.00       8.29
# 2012-01-03   5.29       8.17
# 2012-01-04   5.57       8.13
# 2012-01-05   6.65       8.12
# 2012-01-06   6.00       8.09
# 2012-01-07   6.80       8.09
# 2012-01-08   7.00       8.09
# 2012-01-09   6.30       8.07
# 2012-01-10   7.14       8.02
# 2012-01-11   7.00       8.02
# 2012-01-12   6.51       8.00
# 2012-01-13   6.60       8.04
# 2012-01-14   6.30       8.04
# 2012-01-15   7.15       8.04
# 2012-01-16   7.10       7.99
# 2012-01-17   6.00       7.99
# 2012-01-18   7.10       7.96
# 2012-01-19   6.22       7.85
# 2012-01-20   6.95       7.82

# %%
data["bond_rate_percent_rank"] = data["bond_rate"].rank(pct=True)
data
# Out:
#                close  bond_rate  bond_rate_percent_rank
# date
# 2012-01-01      5.00       8.29                0.878348
# 2012-01-02      5.00       8.29                0.878348
# 2012-01-03      5.29       8.17                0.863043
# 2012-01-04      5.57       8.13                0.855165
# 2012-01-05      6.65       8.12                0.853702
# ...              ...        ...                     ...
# 2024-02-25  51722.00       7.61                0.793270
# 2024-02-26  54524.00       7.63                0.796759
# 2024-02-27  57068.00       7.67                0.801485
# 2024-02-28  62512.00       7.68                0.802611
# 2024-02-29  61161.00       7.68                0.802611
#
# [4443 rows x 3 columns]

# %%
fig, ax1 = plt.subplots(figsize=(10, 6))

# BTC 历史收盘价，用对数刻度
ax1.plot(data.index, data["close"], label="BTC Price", color="b")
ax1.set_yscale("log")
ax1.set_ylabel("BTC Price (log scale)", color="b")

# 创建新的y轴，共享x轴
ax2 = ax1.twinx()

# 高收益债券利率的百分位排名
ax2.plot(data.index, data["bond_rate_percent_rank"], label="High yield bond rate", color="r")
ax2.set_ylabel("High yield bond rate rank", color="r")
ax2.invert_yaxis()  # 百分位排名越高，利率越低

# 添加虚线表示BTC减半事件
halving_dates = ["2012-11-28", "2016-07-09", "2020-05-11"]
for date in halving_dates:
    date = dt.datetime.strptime(date, "%Y-%m-%d")
    ax1.axvline(x=date, color="g", linestyle="--", alpha=0.5)

# %% [markdown]
# 探索两个时间序列变量的先后关系，是否有因果关系。

# %%
# 每日重采样为每月
monthly_data = data.resample("MS").mean()

# 探索X是否领先于Y
# X：垃圾债券利率
# Y：BTC价格，对数价格，月收益率
series_x = monthly_data["bond_rate"]
series_y = np.log(monthly_data["close"])

# 设置最大滞后期k，计算 X(t)和 Y(t-k)的相关性
fig, axes = plt.subplots(nrows=4, ncols=3, figsize=(7, 7), sharey=True, sharex=True)
axes = axes.flatten()
for lag, ax in enumerate(axes):
    sns.scatterplot(x=series_x, y=series_y.shift(-lag), ax=ax)
    corr = series_x.corr(series_y.shift(-lag))
    ax.set_title(f"Lag={lag}({corr:.2f})")
plt.tight_layout()
